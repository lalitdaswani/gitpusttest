# %%
#use in pycharm for pandas reporting
import pandas as pd
import numpy as np
import seaborn as sns
import os
#import ydata_profiling
#from ydata_profiling import ProfileReport


pd.read_csv(r"C:\Users\lalit\Downloads\FitBit data.csv")
df=pd.read_csv(r"C:\Users\lalit\Downloads\FitBit data.csv")
df.head()

#profile = ProfileReport(df, title="Data Profiling Report")
#profile.to_file("data_profile_report.html")
#os.getcwd()
# we don't need categorical date-need to convert in date type.
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.shape
# Out:
# (457, 15)

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
#to find null of sum
df.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
df.dtypes
#activity date should not be the object.
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df["ActivityDate"].unique()
# Out:
# array(['3/25/2016', '3/26/2016', '3/27/2016', '3/28/2016', '3/29/2016',
#        '3/30/2016', '3/31/2016', '4/1/2016', '4/2/2016', '4/3/2016',
#        '4/4/2016', '4/5/2016', '4/6/2016', '4/7/2016', '4/8/2016',
#        '4/9/2016', '4/10/2016', '4/11/2016', '4/12/2016', '3/12/2016',
#        '3/13/2016', '3/14/2016', '3/15/2016', '3/16/2016', '3/17/2016',
#        '3/18/2016', '3/19/2016', '3/20/2016', '3/21/2016', '3/22/2016',
#        '3/23/2016', '3/24/2016'], dtype=object)

# %%
df["Day"]= pd.DatetimeIndex(df["ActivityDate"]).day

# %%
df["Year"]= pd.DatetimeIndex(df["ActivityDate"]).year

# %%
df["Month"]= pd.DatetimeIndex(df["ActivityDate"]).month

# %%
#to correct date create new column date

df["Date"]= pd.DatetimeIndex(df["ActivityDate"])
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df[["ActivityDate","Date","Year","Month","Day"]]
# Out:
#     ActivityDate       Date  Year  Month  Day
# 0      3/25/2016 2016-03-25  2016      3   25
# 1      3/26/2016 2016-03-26  2016      3   26
# 2      3/27/2016 2016-03-27  2016      3   27
# 3      3/28/2016 2016-03-28  2016      3   28
# 4      3/29/2016 2016-03-29  2016      3   29
# ..           ...        ...   ...    ...  ...
# 452     4/8/2016 2016-04-08  2016      4    8
# 453     4/9/2016 2016-04-09  2016      4    9
# 454    4/10/2016 2016-04-10  2016      4   10
# 455    4/11/2016 2016-04-11  2016      4   11
# 456    4/12/2016 2016-04-12  2016      4   12
#
# [457 rows x 5 columns]

# %%
#remove unwanted column, never drop permanently save it another variable
df.drop(["ActivityDate"],axis=1,inplace=True)

# %%
df
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
#plt fig wali coding pehle aayegi
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.boxplot(x="Date",y="Calories",data=df)
plt.show()

# %%
df
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
df["Week"]= pd.DatetimeIndex(df["Date"]).week
# Out:
# C:\Users\lalit\AppData\Local\Temp\ipykernel_9800\3122870071.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df["Week"]= pd.DatetimeIndex(df["Date"]).week

# %%
df
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
#df["Weekday1"] = pd.to_datetime(df["Date"]).dt.strftime("%A")
df["Weekday"] = pd.to_datetime(df["Date"]).dt.day_name()

# %%
#df.drop(["Weekday1"],axis=1,inplace=True)

# %%
df
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366       11004       7.110000         7.110000
# 1    1503960366       17609      11.550000        11.550000
# 2    1503960366       12736       8.530000         8.530000
# 3    1503960366       13231       8.930000         8.930000
# 4    1503960366       12041       7.850000         7.850000
# ..          ...         ...            ...              ...
# 452  8877689391       23014      20.389999        20.389999
# 453  8877689391       16470       8.070000         8.070000
# 454  8877689391       28497      27.530001        27.530001
# 455  8877689391       10622       8.060000         8.060000
# 456  8877689391        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.boxplot(x="Weekday",y= "Calories",data=df)
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='Calories'>

# %%
df.head()
# Out:
#            Id  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366       11004           7.11             7.11
# 1  1503960366       17609          11.55            11.55
# 2  1503960366       12736           8.53             8.53
# 3  1503960366       13231           8.93             8.93
# 4  1503960366       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# ...

# %%
df.columns
# Out:
# Index(['Id', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Day', 'Year',
#        'Month', 'Date', 'Week', 'Weekday'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="Calories",y="TotalSteps",data=df)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='TotalSteps'>

# %%
#building your own library

# %%
#ineuron.ai/EDA collection-git hub library

# %%
stats-1.discriptive
2.inferential

*discriptive:(consists organizing and summarizing) -
    --measuring of central tendency-mean , mediuan mode
    --measure of dispersion  - variance, standard deviation

Inferential:
   -- collect data-> conclusion,inferences-by some experiments->like (ztest, t test1), hypothesis testing, regression analysis, .(on sample data)->
it is done on sample data for another data called population data)

*****{Hypothesis Testing: Involves setting up a null hypothesis and 
    an alternative hypothesis to test assumptions about the population.}
**********************************************************************************************************************

diff between population and samples:
    population(N):
        
    Samples(n):for large population have to take diff diff samples for correct analysis.

*************************************************************************************************
central tendency:
     Population Mean (𝜇)->meu

The population mean is the average of all values in an entire population.

𝜇=∑𝑋/N
Where:

𝜇
μ = population mean
X = each value in the population
N = total number of values in the population

 ** The sample mean is the average of values in a sample (a subset of the population): both formula diff
        mean:
    median helps us to fight outliers.(comparison between mean and meadian)
    mode: to check most frequest no.this also helps.
# Out:
#   Input In [53]
#     stats-1.discriptive
#             ^
# SyntaxError: invalid syntax

# %%
measure of dispersion:   1. variance  2. standard deviation 3. range 4. IQR 5.Mean aboslute deviation 6.cefficient of variation
    variance: means se population data ka spread kesa hai.
        The variance measures the average squared deviation of each data point from the mean.
        variance less  means less dispersion.
        
        high variance  means higher dispersion.
        
    
    
formula changes for sample data:
variance(s 2)=  divided by n-1 hota h isme
why: beacuse it is of sample and dispersion  should reflect  higher than actual dispersion of poulation data.
    Bessel's correction.
    n-1 also called degree of freedom.
    
    
    *******
The standard deviation (σ )is the square root of the variance. It is widely used because it is in the same units as the data.
in case of sample it is (s)

The IQR measures the spread of the middle 50% of the data and is less sensitive to outliers.when arranged in Assec order.
taaki outlies se spread information ko bachane k liye.

The CV is the ratio of the standard deviation to the mean, expressed as a percentage:(% s.d ka means
                                                                                      se taaki dispersion % pta chal sake)
    
    
 ****  Mean Absolute Deviation (MAD) is a statistical measure that quantifies the average amount 
by which each data point in a dataset differs from the mean. 
Unlike variance or standard deviation, which square the differences, MAD uses absolute values, 
making it simpler and less sensitive to extreme values (outliers).
# Out:
#   Input In [54]
#     measure of dispersion:   1. variance  2. standard deviation
#             ^
# SyntaxError: invalid syntax

# %%
#STATS NOTES WORD BOOK
#checking data by qqplot for guassian distribution
import numpy as np
import statsmodels.api as sm
import pylab as py



data_points= np.random.normal(0,1,100)
sm.qqplot(data_points,line="45")
py.show()
#below points on linear represent gaussian distribution

# %%
import seaborn  as sns
sns.displot(data_points)

# %%
import seaborn  as sns
sns.displot(data_points,kind="kde")

# %%
import numpy as np
gfg=np.random.lognormal(0,1,100)
print(gfg)
# Out:
# [1.68443662 1.0101836  3.62068571 1.14004395 0.34960627 1.97441905
#  1.45568017 1.54776106 9.6301933  0.5878415  1.267689   0.59054754
#  0.6852396  0.38954908 2.26904696 0.40207392 1.41022835 4.05221088
#  3.65903826 0.09120624 0.99383166 1.23608014 1.24551109 0.5547431
#  0.40186717 1.5119797  2.18220243 0.25674598 0.78454475 1.22118632
#  0.7486711  0.78636849 3.11914236 0.75290448 0.05882368 1.78461807
#  0.92716598 0.49985317 0.50795582 2.00091641 0.23015667 3.2780967
#  2.14404453 1.35047828 1.06581653 2.40024351 0.8642351  0.28619881
#  0.36525459 2.77533415 2.22929655 0.24997572 1.18907409 0.51084496
#  0.16979059 1.34540225 0.37259716 0.56612918 1.73137462 1.46774197
#  1.4724545  3.68077862 1.16097813 0.4625304  7.80797441 1.17658813
#  0.98175144 6.22606263 0.49341795 4.72653433 0.30309581 2.40233414
#  0.57310947 0.29273903 0.28261719 0.89388066 2.02894268 3.25736024
#  0.15655894 2.34533304 3.50229155 3.23988842 0.27067487 0.84657148
# ...

# %%
#applying log idenfication based on this kind of skewness in diagram
import seaborn  as sns 
sns.displot(data_points,kind="kde")

# %%
#applying log on log normally distributed data
np.log(gfg)
# Out:
# array([ 0.52143116,  0.0101321 ,  1.28666343,  0.13106682, -1.05094769,
#         0.6802742 ,  0.37547326,  0.43680941,  2.2649033 , -0.53129792,
#         0.23719556, -0.52670514, -0.37798671, -0.94276543,  0.8193599 ,
#        -0.91111932,  0.34375164,  1.39926263,  1.29720034, -2.39463191,
#        -0.00618744,  0.2119452 ,  0.21954596, -0.58925015, -0.91163366,
#         0.41341985,  0.78033465, -1.3596681 , -0.24265167,  0.19982278,
#        -0.28945551, -0.24032978,  1.13755808, -0.28381692, -2.83321076,
#         0.57920443, -0.07562268, -0.69344089, -0.67736081,  0.69360528,
#        -1.46899501,  1.18726298,  0.76269401,  0.30045881,  0.0637412 ,
#         0.87557019, -0.14591044, -1.25106856, -1.00716066,  1.02077115,
#         0.80168609, -1.38639148,  0.17317493, -0.67168913, -1.77318943,
#         0.29669304, -0.98725746, -0.568933  ,  0.54891567,  0.38372514,
#         0.38693073,  1.30312431,  0.14926287, -0.771043  ,  2.05514557,
# ...

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py


sm.qqplot(np.log(gfg),line="45")
py.show()

# %%
#pareto

# %%
import numpy as np
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#generating non normal data
original_data= np.random.exponential(size=1000)
#transform training data & save lambda values
fitted_data, fitted_lambda= stats.boxcox(original_data)

#creating axes to draw plots
#it means graph in one row and two colums side by side
fig,ax=plt.subplots(1,2)
#plotting the original data(non-normal) and
#fitted data(normal)
sns.distplot(original_data,hist=False,kde=True,
            kde_kws={"shade":True,"linewidth":2},
            label="Non-normal",color="green",ax=ax[0])
#with fitted data
sns.distplot(fitted_data,hist=False,kde=True,
            kde_kws={"shade":True,"linewidth":2},
            label="normal",color="blue",ax=ax[1])

#adding legends to subplots
plt.legend(loc="upper right")

#rescaling the subplots
fig.set_figheight(5)
fig.set_figwidth(10)
#important coding also
print(f"lambda value used for transformation:{fitted_lambda}")
# Out:
# C:\Users\lalit\anacondaa\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\lalit\anacondaa\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# lambda value used for transformation:0.2822659247804265

# %%
original_data.min()
# Out:
# 0.0006156824981876119

# %%
#checking fitted data, here fitted_data has becaome gaussian distribition , it means original data was pareto distribution
import numpy as np
import statsmodels.api as sm
import pylab as py


sm.qqplot(fitted_data,line="45")
py.show()

# %%
#for creating samples of pareto data
alpha= 2
size=100
samples= (np.random.pareto(alpha,size)+1)

# %%
sns.displot(samples,kind="kde")

# %%
#qq plot by statsprob , using dist =pareto to check pareto by checking alignmemnt as data was pareto data, 
#can't use here dis as normal
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pylab
x_m= 10
alpha= 15
size = 100000
samples= (np.random.pareto(alpha,size)+1)*x_m
stats.probplot(samples,dist="pareto",sparams=(15,10),plot=pylab)
plt.show()
