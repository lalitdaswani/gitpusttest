# %%
import pandas as pd

# %%
pd.read_csv(r'C:\Users\lalit\Downloads\Time (1) - Copy.csv')
# Out:
#    School Code  Ground Employee Code  \
# 0   3020402202                 10212
# 1   3200304517                 10212
# 2   3200105211                 10212
# 3   3140112501                 10212
# 4   3140703203                 10212
# 5   3130201102                 10212
# 6   3130202503                 10212
# 7   3080508402                 10212
# 8   3080506904                 10212
# 9   3210304302                 10212
# 10  3110513902                 10212
# 11  3110811303                 10212
# 12  3040219502                 10212
# 13  3040605004                 10212
# 14  3030411610                 10212
# 15  3090508902                 10212
# 16  3100207802                 10212
# 17  3120205907                 10212
# 18  3120302006                 10212
# 19  3020508003                 10212
# 20  3070607703                 10212
# 21  3220903503                 10212
# 22  3180312208                 10212
# 23  3160104402                 10212
# ...

# %%
pd= pd.read_csv(r'C:\Users\lalit\Downloads\Time (1) - Copy.csv')

# %%
pd
# Out:
#    School Code  Ground Employee Code  \
# 0   3020402202                 10212
# 1   3200304517                 10212
# 2   3200105211                 10212
# 3   3140112501                 10212
# 4   3140703203                 10212
# 5   3130201102                 10212
# 6   3130202503                 10212
# 7   3080508402                 10212
# 8   3080506904                 10212
# 9   3210304302                 10212
# 10  3110513902                 10212
# 11  3110811303                 10212
# 12  3040219502                 10212
# 13  3040605004                 10212
# 14  3030411610                 10212
# 15  3090508902                 10212
# 16  3100207802                 10212
# 17  3120205907                 10212
# 18  3120302006                 10212
# 19  3020508003                 10212
# 20  3070607703                 10212
# 21  3220903503                 10212
# 22  3180312208                 10212
# 23  3160104402                 10212
# ...

# %%
pd.head()
# Out:
#   School Code  Ground Employee Code  \
# 0  3020402202                 10212
# 1  3200304517                 10212
# 2  3200105211                 10212
# 3  3140112501                 10212
# 4  3140703203                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
# 2  Y13 Interested School: phone unavailable, What...  27-12-2021 00:00  10:30
# 3  YR1 No Response: Call went through. Nobody pic...  27-12-2021 00:00  10:38
# 4  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:45
#
#   Difference
# 0      00:12
# 1      00:12
# 2      00:08
# 3      00:07
# 4      00:09

# %%
pd.head(10)
# Out:
#   School Code  Ground Employee Code  \
# 0  3020402202                 10212
# 1  3200304517                 10212
# 2  3200105211                 10212
# 3  3140112501                 10212
# 4  3140703203                 10212
# 5  3130201102                 10212
# 6  3130202503                 10212
# 7  3080508402                 10212
# 8  3080506904                 10212
# 9  3210304302                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
# 2  Y13 Interested School: phone unavailable, What...  27-12-2021 00:00  10:30
# 3  YR1 No Response: Call went through. Nobody pic...  27-12-2021 00:00  10:38
# 4  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:45
# 5  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:54
# ...

# %%
pd.tail(2)
# Out:
#    School Code  Ground Employee Code  \
# 41    PB060387                 10212
# 42  3190700302                 10212
#
#                                               Remarks        Remarks Da  \
# 41  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00
# 42  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00
#
#      Time                                         Difference
# 41  16:39                                              00:44
# 42  17:23  ##############################################...

# %%
#pehle pd ko data frame bnaya tha isle
df= pd.read_csv(r'C:\Users\lalit\Downloads\Time (1) - Copy.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 #pehle pd ko data frame bnaya tha isle
# ----> 2 df= pd.read_csv(r'C:\Users\lalit\Downloads\Time (1) - Copy.csv')
#
# File ~\anacondaa\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\lalit\Downloads\Time (1) - Copy.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= df.head(2)

# %%
df1.to_csv("test.csv")

# %%
pwd()
# Out:
# 'C:\\Users\\lalit'

# %%
pd.read_csv("C:\\Users\\lalit\\test.csv")
# Out:
#    Unnamed: 0  School Code  Ground Employee Code  \
# 0           0   3020402202                 10212
# 1           1   3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
df.head(2)
# Out:
#   School Code  Ground Employee Code  \
# 0  3020402202                 10212
# 1  3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
df2=pd.read_csv("C:\\Users\\lalit\\test2.csv")

# %%
#opening csv file but withput , instead by #
df2
# Out:
#   #School Code#Ground Employee Code#Remarks#Remarks Da#Time#Difference
# 0  0#3020402202#10212#Y2 Interested School: Had a...
# 1  1#3200304517#10212#Y2 Interested School: Had a...

# %%
#cooorect way to open
df2=pd.read_csv("C:\\Users\\lalit\\test2.csv",sep='#')

# %%
df2
# Out:
#    Unnamed: 0  School Code  Ground Employee Code  \
# 0           0   3020402202                 10212
# 1           1   3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
#suppose witgh no header in data
df=pd.read_csv("C:\\Users\\lalit\\test2.csv",sep='#',header=None)

# %%
#naming columns
pd.read_csv("C:\\Users\\lalit\\test2.csv",sep='#',header=None,names= ["a","b","c","d","e","f","g"])
# Out:
#      a            b                     c  \
# 0  NaN  School Code  Ground Employee Code
# 1  0.0   3020402202                 10212
# 2  1.0   3200304517                 10212
#
#                                                    d                 e      f  \
# 0                                            Remarks        Remarks Da   Time
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 2  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#             g
# 0  Difference
# 1       00:12
# 2       00:12

# %%
pd.read_csv("C:\\Users\\lalit\\test2.csv",sep='#',header=None,names= ["a","b","c","d","e","f","g"],skiprows=[2])
# Out:
#      a            b                     c  \
# 0  NaN  School Code  Ground Employee Code
# 1  0.0   3020402202                 10212
#
#                                                    d                 e      f  \
# 0                                            Remarks        Remarks Da   Time
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
#
#             g
# 0  Difference
# 1       00:12

# %%
pd.read_csv("C:\\Users\\lalit\\test2.csv",sep='#',header=None,names= ["a","b","c","d","e","f","g"],skiprows=[2],na_values=[10212])
# Out:
#      a            b                     c  \
# 0  NaN  School Code  Ground Employee Code
# 1  0.0   3020402202                   NaN
#
#                                                    d                 e      f  \
# 0                                            Remarks        Remarks Da   Time
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
#
#             g
# 0  Difference
# 1       00:12

# %%
df2
# Out:
#    Unnamed: 0  School Code  Ground Employee Code  \
# 0           0   3020402202                 10212
# 1           1   3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
#count se 
df2.describe()
# Out:
#        Unnamed: 0   School Code  Ground Employee Code
# count    2.000000  2.000000e+00                   2.0
# mean     0.500000  3.110353e+09               10212.0
# std      0.707107  1.272101e+08                   0.0
# min      0.000000  3.020402e+09               10212.0
# 25%      0.250000  3.065378e+09               10212.0
# 50%      0.500000  3.110353e+09               10212.0
# 75%      0.750000  3.155329e+09               10212.0
# max      1.000000  3.200305e+09               10212.0

# %%
df2.dtypes
# Out:
# Unnamed: 0               int64
# School Code              int64
# Ground Employee Code     int64
# Remarks                 object
# Remarks Da              object
# Time                    object
# Difference              object
# dtype: object

# %%
df2
# Out:
#    Unnamed: 0  School Code  Ground Employee Code  \
# 0           0   3020402202                 10212
# 1           1   3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
df2.to_csv("testx.csv", index = False ,sep="#", columns=["School Code","Remarks"])

# %%
pwd()
# Out:
# 'C:\\Users\\lalit'

# %%
df2
# Out:
#    Unnamed: 0  School Code  Ground Employee Code  \
# 0           0   3020402202                 10212
# 1           1   3200304517                 10212
#
#                                              Remarks        Remarks Da   Time  \
# 0  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:06
# 1  Y2 Interested School: Had a word with the Prin...  27-12-2021 00:00  10:18
#
#   Difference
# 0      00:12
# 1      00:12

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'School Code', 'Ground Employee Code', 'Remarks',
#        'Remarks Da', 'Time', 'Difference'],
#       dtype='object')

# %%
#single column details
df2["Time"]
# Out:
# 0    10:06
# 1    10:18
# Name: Time, dtype: object

# %%
#SINGLE REORD CALLED SERIES
#TABULAR CALLED DATA FRAME
type(df2["Time"])
# Out:
# pandas.core.series.Series

# %%
#MAKing it data frame
type(df2[["Time"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df2[["Time"]]
# Out:
#     Time
# 0  10:06
# 1  10:18

# %%
#can't call multiple columns  this way
df2["Time","School Code"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anacondaa\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anacondaa\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anacondaa\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Time', 'School Code')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#to  call multiple column
df2[["Time","School Code"]]
# Out:
#     Time  School Code
# 0  10:06   3020402202
# 1  10:18   3200304517

# %%
pd.read_excel(r"C:\Users\lalit\Downloads\Time (1) - Copy.xlsx" ,sheet_name="Ragini")
# Out:
#    School Code  Ground Employee Code  \
# 0   3020402202                 10212
# 1   3200304517                 10212
# 2   3200105211                 10212
# 3   3140112501                 10212
# 4   3140703203                 10212
# 5   3130201102                 10212
# 6   3130202503                 10212
# 7   3080508402                 10212
# 8   3080506904                 10212
# 9   3210304302                 10212
# 10  3110513902                 10212
# 11  3110811303                 10212
# 12  3040219502                 10212
# 13  3040605004                 10212
# 14  3030411610                 10212
# 15  3090508902                 10212
# 16  3100207802                 10212
# 17  3120205907                 10212
# 18  3120302006                 10212
# 19  3020508003                 10212
# 20  3070607703                 10212
# 21  3220903503                 10212
# 22  3180312208                 10212
# 23  3160104402                 10212
# ...

# %%
df3=pd.read_excel(r"C:\Users\lalit\Downloads\Time (1) - Copy.xlsx" ,sheet_name="Ragini")

# %%
df4=pd.read_html("https://afraenkel.github.io/ds-in-practice/content/02/tabular-data.html")

# %%
df4
# Out:
# [  Respondent Id     Name      Job Title Favorite Color Age
#  0           120    Alice            CEO          Green  47
#  1           121      Bob  Store Manager         Yellow  35
#  2           122      Cai         Writer         Orange  38
#  3           129  Daniela       Engineer           Pink  26
#  4             …        …              …              …   …,
#     Unnamed: 0     Name      Job Title Favorite Color  Age
#  0           0    Alice            CEO          Green   47
#  1           1      Bob  Store Manager         Yellow   35
#  2           2      Cai         Writer         Orange   38
#  3           3  Daniela       Engineer           Pink   26
#  4           4   Erykah      Marketing           Blue   24,
#     Unnamed: 0     Name      Job Title Favorite Color  Age
#  0           0    Alice            CEO          Green   47
#  1           1      Bob  Store Manager         Yellow   35
#  2           2      Cai         Writer         Orange   38
# ...

# %%
#means contains 6 tables
len(df4)
# Out:
# 6

# %%
#list is because have multiple tables
type(df4)
# Out:
# list

# %%
df4[1]
# Out:
#    Unnamed: 0     Name      Job Title Favorite Color  Age
# 0           0    Alice            CEO          Green   47
# 1           1      Bob  Store Manager         Yellow   35
# 2           2      Cai         Writer         Orange   38
# 3           3  Daniela       Engineer           Pink   26
# 4           4   Erykah      Marketing           Blue   24

# %%
df4[1].to_csv("data format.csv")

# %%
#pd.read_csv("websit link containingcsv daTA")

# %%
s="""{"name":"sudh",
"phone_no": 4565,
"comp":["ineuron","ey","unilever","verizon","deloitee"]}"""

# %%
import json

# %%
json.loads(s)
# Out:
# {'name': 'sudh',
#  'phone_no': 4565,
#  'comp': ['ineuron', 'ey', 'unilever', 'verizon', 'deloitee']}

# %%
s1=json.loads(s)

# %%
s1
# Out:
# {'name': 'sudh',
#  'phone_no': 4565,
#  'comp': ['ineuron', 'ey', 'unilever', 'verizon', 'deloitee']}

# %%
#converting fdata into tabular format
pd.DataFrame(s1)
# Out:
#    name  phone_no      comp
# 0  sudh      4565   ineuron
# 1  sudh      4565        ey
# 2  sudh      4565  unilever
# 3  sudh      4565   verizon
# 4  sudh      4565  deloitee

# %%
#only with string data otherwise with index
pd.DataFrame(s1,columns=["comp"])
# Out:
#        comp
# 0   ineuron
# 1        ey
# 2  unilever
# 3   verizon
# 4  deloitee

# %%
import requests

# %%
#due to url has json format data
res=requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js=res.json()

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60170',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60170/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60170/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/60170/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/60170',
#   'id': 2629924972,
#   'node_id': 'PR_kwDOAA0YD86ArMWe',
#   'number': 60170,
#   'title': 'DOC: Update contributing docs for Windows build tools instructions',
#   'user': {'login': 'Ravenin7',
#    'id': 99545557,
#    'node_id': 'U_kgDOBe7x1Q',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99545557?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ravenin7',
#    'html_url': 'https://github.com/Ravenin7',
# ...

# %%
# we are getting because all data was under the list
#js[o] inse key value wale set niklenege
js[1]["title"]
# Out:
# "BUG: build_table_schema (AttributeError: 'datetime.timezone' object has no attribute 'zone')"

# %%
for i in range(len(js)):
    print(js[i]["title"])
# Out:
# DOC: Update contributing docs for Windows build tools instructions
# BUG: build_table_schema (AttributeError: 'datetime.timezone' object has no attribute 'zone')
# BUG: fix #60128 BUG: Series.combine_first loss of precision
# QST: Why Doesn't Pandas Have an Insert Index Function or Method?
# ENH: "stripna" for dropping leading or trailing NaNs
# ENH: Add `area_limit` to `fillna
# BUG/API: preserve dtype in Index `append()`
# CI: add test build with numpy 1.26 (<2)
# BUG: Docs won't build (Unexpected exception in `doc\source\user_guide\enhancingperf.rst`)
# DOC: pandas.DataFrame.to_html additional description for the border parameter
# CI: Add Windows wheels for the free-threaded build
# [backport 2.3.x] TST (string dtype): add explicit object vs str dtype to index fixture (#60116)
# TST (string dtype): remove xfails in extension tests + fix categorical/string dispatch
# ENH: allow complex type inference in convert_dtypes
# BUG: Series.combine_first loss of precision
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(js,columns=["url","title"])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js,columns=["url","user"])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#user column nahi aa paya kyuki data bda h mutple key value pair aur h uske andar isliye csv mein karenge pura data k liye

pd.DataFrame(js).head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
df5=pd.DataFrame(js).head()

# %%
#to check complte user data as user also contains dictonories
df5.to_csv("jsontry.csv")

# %%
js[0]["user"]
# Out:
# {'login': 'Ravenin7',
#  'id': 99545557,
#  'node_id': 'U_kgDOBe7x1Q',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/99545557?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Ravenin7',
#  'html_url': 'https://github.com/Ravenin7',
#  'followers_url': 'https://api.github.com/users/Ravenin7/followers',
#  'following_url': 'https://api.github.com/users/Ravenin7/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Ravenin7/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Ravenin7/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Ravenin7/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Ravenin7/orgs',
#  'repos_url': 'https://api.github.com/users/Ravenin7/repos',
#  'events_url': 'https://api.github.com/users/Ravenin7/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Ravenin7/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
# ...

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#user data ka compilation in datya frame as it contains json under json
lis=[]
for i in range(len(js)):
    
    
    
    lis.append(js[i]["user"])
               
     
pd.DataFrame(lis)
# Out:
#                             login         id               node_id  \
# 0                        Ravenin7   99545557          U_kgDOBe7x1Q
# 1                           rteqs   29604017  MDQ6VXNlcjI5NjA0MDE3
# 2                     cooolheater  184128544          U_kgDOCvmUIA
# 3                        MasonDye  108563824          U_kgDOBniNcA
# 4                    joshdunnlime   89857735  MDQ6VXNlcjg5ODU3NzM1
# 5                    joshdunnlime   89857735  MDQ6VXNlcjg5ODU3NzM1
# 6              jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 7              jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 8                        Ravenin7   99545557          U_kgDOBe7x1Q
# 9                          ivor25   61209767  MDQ6VXNlcjYxMjA5NzY3
# 10                    lysnikolaou   20306270  MDQ6VXNlcjIwMzA2Mjcw
# 11             jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 12             jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# ...

# %%
#or, by
json_data=pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data =pd.DataFrame.from_records(json_data["user"])

# %%
data
# Out:
#                             login         id               node_id  \
# 0                        Ravenin7   99545557          U_kgDOBe7x1Q
# 1                           rteqs   29604017  MDQ6VXNlcjI5NjA0MDE3
# 2                     cooolheater  184128544          U_kgDOCvmUIA
# 3                        MasonDye  108563824          U_kgDOBniNcA
# 4                    joshdunnlime   89857735  MDQ6VXNlcjg5ODU3NzM1
# 5                    joshdunnlime   89857735  MDQ6VXNlcjg5ODU3NzM1
# 6              jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 7              jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 8                        Ravenin7   99545557          U_kgDOBe7x1Q
# 9                          ivor25   61209767  MDQ6VXNlcjYxMjA5NzY3
# 10                    lysnikolaou   20306270  MDQ6VXNlcjIwMzA2Mjcw
# 11             jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 12             jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# ...
